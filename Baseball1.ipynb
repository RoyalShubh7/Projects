# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# columns infrmation:

# W – Win: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work (also related: winning percentage)
# R – Runs scored: number of times a player crosses home plate
# AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
# H – Hit: reaching base because of a batted, fair ball without error by the defense
# 2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error
# 3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
# HR – Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error
# BB – Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first base.
# SO – Strikeout: number of batters who received strike three
# SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense
# RA – Run average: number of runs allowed times nine divided by innings pitched
# ER – Earned run: number of runs that did not occur as a result of errors or passed balls
# ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
# CG – Complete game: number of games where player was the only pitcher for their team
# SHO – Shutout: number of complete games pitched with no runs allowed
# SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game 
#       (b) the potential tying run was on base, at bat, or on deck; 
#       (c) the pitcher pitched three or more innings
# E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result

# %%
# EDA Checking:-

df.isnull().sum()


# Hence there are NO any null values in the dataset.
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
# Visualization of DATA:


import seaborn as sns
import matplotlib.pyplot as plt
from  plotly.subplots import make_subplots

# %%
df_continuous= df[['W','R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']].copy

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="R",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="R",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="R",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="AB",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="AB",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="AB",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="H",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="H",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="H",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="2B",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="2B",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="2B",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="3B",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="3B",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="3B",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="HR",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="HR",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="HR",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="BB",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="BB",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="BB",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="SO",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="SO",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="SO",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="SB",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="SB",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="SB",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="RA",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="RA",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="RA",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="ER",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="ER",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="ER",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="ERA",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="ERA",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="ERA",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="CG",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="CG",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="CG",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="SHO",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="SHO",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="SHO",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="SV",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="SV",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="SV",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="E",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="E",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="E",data=df)
plt.show()

# %%
# 1) From above Visualization I conclude that R, HR, 2B, SV, SHO, BB this columns datas are highly positively linearly corelated and Having the randomness in some columns
# 2) The column data SB, RA, ER this column data are highly negetively corelated.
# 3) The Column AB, H, SO, ERA, CG, E this columns are having too less features and are very less corelated to W
# 4) The data set has the outliners present and is in the randomness.

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
plt.figure(figsize = (29,9))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
# SV has the 67% correleated with W and considered as good bond.

# %%
# Describing the datatset:

df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
plt.figure(figsize=(25,12))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor='white',fmt='0.2f')
plt.yticks(fontsize=12)
plt.title("variable summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df["ERA"] = df["ERA"].astype(int)

# %%
df.dtypes
# Out:
# W      int64
# R      int64
# AB     int64
# H      int64
# 2B     int64
# 3B     int64
# HR     int64
# BB     int64
# SO     int64
# SB     int64
# RA     int64
# ER     int64
# ERA    int64
# CG     int64
# SHO    int64
# SV     int64
# E      int64
# dtype: object

# %%
# From above we have the column data type.
# Also we had done the outliners checking in visualizton part 
# so more outliers are present in the E column which we can drop the column due to have very less correlation we target variable.
# while also the outers are SV, SHO, ERA, R column

# %%
df1 = df.drop(columns=['E', 'ERA'])
df1
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER  CG  SHO  SV
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601   2    8  56
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653   2   12  45
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  11   10  38
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643   7    9  37
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746   7   12  35
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609   7   10  34
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652   3    4  48
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646   0   10  43
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604   1   12  60
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694   3   10  40
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680   5    9  45
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572   5   13  39
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630   2   12  46
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677   6   12  45
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664   5   15  28
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478   1   15  62
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532   0   13  54
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546   6   21  48
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682   1    7  40
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700   2    8  35
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557   1   14  50
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577   4   13  41
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638   0   12  35
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698   3   10  44
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749   1    7  35
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553   6   21  47
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597   7   18  41
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659   1   12  44
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655   1    6  41
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799   4    4  36

# %%
df1.shape
# Out:
# (30, 15)

# %%
# Split Data Into to the dependent and independent variables:

x = df1.drop("W",axis=1)
y = df1["W"]

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER  CG  SHO  SV
# 0   724  5575  1497  300  42  139  383   973  104  641  601   2    8  56
# 1   696  5467  1349  277  44  156  439  1264   70  700  653   2   12  45
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  11   10  38
# 3   622  5533  1381  260  27  136  404  1231   68  701  643   7    9  37
# 4   689  5605  1515  289  49  151  455  1259   83  803  746   7   12  35
# 5   891  5509  1480  308  17  232  570  1151   88  670  609   7   10  34
# 6   764  5567  1397  272  19  212  554  1227   63  698  652   3    4  48
# 7   713  5485  1370  246  20  217  418  1331   44  693  646   0   10  43
# 8   644  5485  1383  278  32  167  436  1310   87  642  604   1   12  60
# 9   748  5640  1495  294  33  161  478  1148   71  753  694   3   10  40
# 10  751  5511  1419  279  32  172  503  1233  101  733  680   5    9  45
# 11  729  5459  1363  278  26  230  486  1392  121  618  572   5   13  39
# 12  661  5417  1331  243  21  176  435  1150   52  675  630   2   12  46
# 13  656  5544  1379  262  22  198  478  1336   69  726  677   6   12  45
# 14  694  5600  1405  277  46  146  475  1119   78  729  664   5   15  28
# 15  647  5484  1386  288  39  137  506  1267   69  525  478   1   15  62
# 16  697  5631  1462  292  27  140  461  1322   98  596  532   0   13  54
# 17  689  5491  1341  272  30  171  567  1518   95  608  546   6   21  48
# 18  655  5480  1378  274  34  145  412  1299   84  737  682   1    7  40
# 19  640  5571  1382  257  27  167  496  1255  134  754  700   2    8  35
# 20  683  5527  1351  295  17  177  488  1290   51  613  557   1   14  50
# 21  703  5428  1363  265  13  177  539  1344   57  635  577   4   13  41
# 22  613  5463  1420  236  40  120  375  1150  112  678  638   0   12  35
# 23  573  5420  1361  251  18  100  471  1107   69  760  698   3   10  44
# 24  626  5529  1374  272  37  130  387  1274   88  809  749   1    7  35
# 25  667  5385  1346  263  26  187  563  1258   59  595  553   6   21  47
# 26  696  5565  1486  288  39  136  457  1159   93  627  597   7   18  41
# 27  720  5649  1494  289  48  154  490  1312  132  713  659   1   12  44
# 28  650  5457  1324  260  36  148  426  1327   82  731  655   1    6  41
# 29  737  5572  1479  274  49  186  388  1283   97  844  799   4    4  36

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
print(x.shape)
print(y.shape)
# Out:
# (30, 14)
# (30,)

# %%
# checking for the skewness
import seaborn as sns

x.skew().sort_values(ascending=False)
sns.displot(x)

# %%
# here we can see that skewness present in R,CG,H SV columns.
# we will remove the skewness by the power transformation technique.

# %%
from sklearn.preprocessing import power_transform
import seaborn as sns
x_new = power_transform(x)
sns.displot(x_new)

# %%
# checking for the skewness again

pd.DataFrame(x_new , columns=x.columns).skew().sort_values(ascending=False)
# Out:
# SO     0.041170
# SHO    0.006560
# SV     0.000836
# R      0.000000
# AB     0.000000
# H      0.000000
# HR    -0.000065
# ER    -0.001940
# BB    -0.007760
# RA    -0.008082
# SB    -0.010455
# 2B    -0.035315
# CG    -0.059785
# 3B    -0.072933
# dtype: float64

# %%
# validating skewness is removed or not

x.skew().sort_values(ascending= False)
# Out:
# R      1.200786
# CG     0.736845
# H      0.670254
# SV     0.657524
# SHO    0.565790
# HR     0.516441
# SB     0.479893
# AB     0.183437
# BB     0.158498
# 3B     0.129502
# ER     0.058710
# RA     0.045734
# SO    -0.156065
# 2B    -0.230650
# dtype: float64

# %%
sk = x.skew()

# %%
sk
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# dtype: float64

# %%
np.abs(3)
# Out:
# 3

# %%
np.abs(-3)
# Out:
# 3

# %%
sk[np.abs(sk)>0.75]
# Out:
# R    1.200786
# dtype: float64

# %%
x.skew()[np.abs(x.skew())<0.65].all()


# hence skewness has been removed.
# Out:
# True

# %%
# checking for the outliners  

# Removing the outliers:

# Z Score Technique:

from scipy.stats import zscore
z=np.abs(zscore(x))
z.shape
# Out:
# (30, 14)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5]), array([0]))

# %%
x_new=x[(z<3).all(axis=1)]
print(x.shape)
print(x_new.shape)
# Out:
# (30, 14)
# (29, 14)

# %%
# checking the still outliers are present or not if they ARE present the they help in testing model or not



from scipy.stats import zscore
(np.abs(zscore(x))<3).all()
# Out:
# R      False
# AB      True
# H       True
# 2B      True
# 3B      True
# HR      True
# BB      True
# SO      True
# SB      True
# RA      True
# ER      True
# CG      True
# SHO     True
# SV      True
# dtype: bool

# %%
# Trainning The MODEL

# Finding the best random state:


from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = i)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    pred_test = lr.predict(x_test)
    pred_train = lr.predict(x_train)
    
    print(f"At random state {i}, the training accuracy is:- {r2_score(y_train, pred_train)}")
    print(f"At randoom stae {i}, the training accuracy is:- {r2_score(y_test, pred_test)}")
    print("\n")
# Out:
# At random state 0, the training accuracy is:- 0.9487592371905161
# At randoom stae 0, the training accuracy is:- 0.7648782166231379
#
#
# At random state 1, the training accuracy is:- 0.9642843879225463
# At randoom stae 1, the training accuracy is:- 0.6611606121103019
#
#
# At random state 2, the training accuracy is:- 0.9654327796675859
# At randoom stae 2, the training accuracy is:- 0.5225500145457921
#
#
# At random state 3, the training accuracy is:- 0.9649168230149042
# At randoom stae 3, the training accuracy is:- 0.6592278460810308
#
#
# At random state 4, the training accuracy is:- 0.955341654572888
# At randoom stae 4, the training accuracy is:- 0.572413947420529
#
#
# At random state 5, the training accuracy is:- 0.942478862578803
# At randoom stae 5, the training accuracy is:- 0.848219935885935
#
#
# At random state 6, the training accuracy is:- 0.9386223001987456
# At randoom stae 6, the training accuracy is:- 0.6829115444817457
#
#
# At random state 7, the training accuracy is:- 0.9452665038036192
# At randoom stae 7, the training accuracy is:- 0.4834051677287571
#
#
# At random state 8, the training accuracy is:- 0.9615314845103102
# At randoom stae 8, the training accuracy is:- 0.600357209437703
#
#
# At random state 9, the training accuracy is:- 0.9529722988710221
# At randoom stae 9, the training accuracy is:- 0.7103968137825403
#
#
# At random state 10, the training accuracy is:- 0.9561631024765893
# At randoom stae 10, the training accuracy is:- 0.2758805079961866
#
#
# At random state 11, the training accuracy is:- 0.9777043896630374
# At randoom stae 11, the training accuracy is:- 0.15214103475580865
#
#
# At random state 12, the training accuracy is:- 0.9617750073940041
# At randoom stae 12, the training accuracy is:- 0.31053516602093256
#
#
# At random state 13, the training accuracy is:- 0.9728548077521487
# At randoom stae 13, the training accuracy is:- 0.6712267838295013
#
#
# At random state 14, the training accuracy is:- 0.9431650401029166
# At randoom stae 14, the training accuracy is:- 0.7904402967435882
#
#
# At random state 15, the training accuracy is:- 0.9618660679920955
# At randoom stae 15, the training accuracy is:- 0.5355458208762367
#
#
# At random state 16, the training accuracy is:- 0.9807528298709064
# At randoom stae 16, the training accuracy is:- 0.30552232511471555
#
#
# At random state 17, the training accuracy is:- 0.9662275709859808
# At randoom stae 17, the training accuracy is:- 0.18018793580084214
#
#
# At random state 18, the training accuracy is:- 0.9534663820874194
# At randoom stae 18, the training accuracy is:- 0.5933755145402093
#
#
# At random state 19, the training accuracy is:- 0.9438378444424755
# At randoom stae 19, the training accuracy is:- 0.8686644943623453
#
#
# At random state 20, the training accuracy is:- 0.9596646518320209
# At randoom stae 20, the training accuracy is:- 0.4246909596471127
#
#
# At random state 21, the training accuracy is:- 0.956615547732735
# At randoom stae 21, the training accuracy is:- 0.49084401205568573
#
#
# At random state 22, the training accuracy is:- 0.9385623040762426
# At randoom stae 22, the training accuracy is:- 0.8584291713549009
#
#
# At random state 23, the training accuracy is:- 0.9581805698205527
# At randoom stae 23, the training accuracy is:- 0.5720441909239162
#
#
# At random state 24, the training accuracy is:- 0.9857027626734709
# At randoom stae 24, the training accuracy is:- -2.9192077520982656
#
#
# At random state 25, the training accuracy is:- 0.945467459984106
# At randoom stae 25, the training accuracy is:- 0.5712733276922868
#
#
# At random state 26, the training accuracy is:- 0.9527980398585235
# At randoom stae 26, the training accuracy is:- 0.7146105747829475
#
#
# At random state 27, the training accuracy is:- 0.941109181304131
# At randoom stae 27, the training accuracy is:- 0.9333854945491913
#
#
# At random state 28, the training accuracy is:- 0.9583457859493205
# At randoom stae 28, the training accuracy is:- 0.5939533493958512
#
#
# At random state 29, the training accuracy is:- 0.9478658385746678
# At randoom stae 29, the training accuracy is:- 0.8319843092689315
#
#
# At random state 30, the training accuracy is:- 0.9348859958091773
# At randoom stae 30, the training accuracy is:- 0.9134623930966392
#
#
# At random state 31, the training accuracy is:- 0.9868357776495169
# At randoom stae 31, the training accuracy is:- 0.2540383812864455
#
#
# At random state 32, the training accuracy is:- 0.9536809050093479
# At randoom stae 32, the training accuracy is:- 0.3458012620853803
#
#
# At random state 33, the training accuracy is:- 0.9788092205222534
# At randoom stae 33, the training accuracy is:- 0.7273458933227037
#
#
# At random state 34, the training accuracy is:- 0.9682475017221726
# At randoom stae 34, the training accuracy is:- 0.7911604189790333
#
#
# At random state 35, the training accuracy is:- 0.9716032071407795
# At randoom stae 35, the training accuracy is:- 0.6232056251368572
#
#
# At random state 36, the training accuracy is:- 0.9388343833618106
# At randoom stae 36, the training accuracy is:- 0.8933477138862921
#
#
# At random state 37, the training accuracy is:- 0.9441968712264535
# At randoom stae 37, the training accuracy is:- 0.8298150567290778
#
#
# At random state 38, the training accuracy is:- 0.9517246682131343
# At randoom stae 38, the training accuracy is:- 0.6573054899715101
#
#
# At random state 39, the training accuracy is:- 0.9425404108018333
# At randoom stae 39, the training accuracy is:- 0.910139366929183
#
#
# At random state 40, the training accuracy is:- 0.9659576126270837
# At randoom stae 40, the training accuracy is:- 0.6157177506085261
#
#
# At random state 41, the training accuracy is:- 0.948823415834858
# At randoom stae 41, the training accuracy is:- 0.776252714173485
#
#
# At random state 42, the training accuracy is:- 0.9706828317422187
# At randoom stae 42, the training accuracy is:- 0.7501812469863017
#
#
# At random state 43, the training accuracy is:- 0.9808658639545884
# At randoom stae 43, the training accuracy is:- -0.2583043176982942
#
#
# At random state 44, the training accuracy is:- 0.9477300106300547
# At randoom stae 44, the training accuracy is:- 0.7765608044256594
#
#
# At random state 45, the training accuracy is:- 0.9412202345127149
# At randoom stae 45, the training accuracy is:- 0.8941991034962237
#
#
# At random state 46, the training accuracy is:- 0.9555674227026631
# At randoom stae 46, the training accuracy is:- 0.6691969296757025
#
#
# At random state 47, the training accuracy is:- 0.9412033690817132
# At randoom stae 47, the training accuracy is:- 0.9252524391626431
#
#
# At random state 48, the training accuracy is:- 0.9370576660091801
# At randoom stae 48, the training accuracy is:- 0.9313177747696249
#
#
# At random state 49, the training accuracy is:- 0.9734770778611125
# At randoom stae 49, the training accuracy is:- 0.6204371816150449
#
#
# At random state 50, the training accuracy is:- 0.9707040149277426
# At randoom stae 50, the training accuracy is:- 0.7525419381243259
#
#
# At random state 51, the training accuracy is:- 0.9748564575791681
# At randoom stae 51, the training accuracy is:- 0.4494202711290274
#
#
# At random state 52, the training accuracy is:- 0.9735359310483355
# At randoom stae 52, the training accuracy is:- 0.48093247912179093
#
#
# At random state 53, the training accuracy is:- 0.9844792240628744
# At randoom stae 53, the training accuracy is:- 0.24776856205738418
#
#
# At random state 54, the training accuracy is:- 0.9449087034660186
# At randoom stae 54, the training accuracy is:- 0.9204529148343044
#
#
# At random state 55, the training accuracy is:- 0.9504892491446014
# At randoom stae 55, the training accuracy is:- 0.8039636656166196
#
#
# At random state 56, the training accuracy is:- 0.9489962634110005
# At randoom stae 56, the training accuracy is:- 0.7952268489116346
#
#
# At random state 57, the training accuracy is:- 0.9716247824282316
# At randoom stae 57, the training accuracy is:- -0.21643916388741546
#
#
# At random state 58, the training accuracy is:- 0.9304691521719912
# At randoom stae 58, the training accuracy is:- 0.8146324972557326
#
#
# At random state 59, the training accuracy is:- 0.9831337341049412
# At randoom stae 59, the training accuracy is:- 0.3689407590896384
#
#
# At random state 60, the training accuracy is:- 0.9719160605132909
# At randoom stae 60, the training accuracy is:- 0.619895321064257
#
#
# At random state 61, the training accuracy is:- 0.9663532546600236
# At randoom stae 61, the training accuracy is:- 0.5838750207820484
#
#
# At random state 62, the training accuracy is:- 0.9501002467259254
# At randoom stae 62, the training accuracy is:- 0.6413539543159741
#
#
# At random state 63, the training accuracy is:- 0.9547528615730674
# At randoom stae 63, the training accuracy is:- 0.49291823817473523
#
#
# At random state 64, the training accuracy is:- 0.9496691662884462
# At randoom stae 64, the training accuracy is:- 0.7183710757794655
#
#
# At random state 65, the training accuracy is:- 0.9346805751242158
# At randoom stae 65, the training accuracy is:- 0.8907249816445316
#
#
# At random state 66, the training accuracy is:- 0.9851478555259711
# At randoom stae 66, the training accuracy is:- 0.20427379350392427
#
#
# At random state 67, the training accuracy is:- 0.9330258313578781
# At randoom stae 67, the training accuracy is:- 0.9072261377194546
#
#
# At random state 68, the training accuracy is:- 0.934794020216509
# At randoom stae 68, the training accuracy is:- 0.9404495703808292
#
#
# At random state 69, the training accuracy is:- 0.9497306432335028
# At randoom stae 69, the training accuracy is:- 0.8510029449168782
#
#
# At random state 70, the training accuracy is:- 0.9501971300828713
# At randoom stae 70, the training accuracy is:- 0.8068410433046196
#
#
# At random state 71, the training accuracy is:- 0.9622275360922883
# At randoom stae 71, the training accuracy is:- 0.36998081840712693
#
#
# At random state 72, the training accuracy is:- 0.9520206332250443
# At randoom stae 72, the training accuracy is:- 0.8356568904398709
#
#
# At random state 73, the training accuracy is:- 0.9616995756596223
# At randoom stae 73, the training accuracy is:- 0.7329304260484109
#
#
# At random state 74, the training accuracy is:- 0.9803457428268054
# At randoom stae 74, the training accuracy is:- -1.4650886676215071
#
#
# At random state 75, the training accuracy is:- 0.9431616210906754
# At randoom stae 75, the training accuracy is:- 0.7380975909600298
#
#
# At random state 76, the training accuracy is:- 0.9648135585339849
# At randoom stae 76, the training accuracy is:- 0.5850770315728894
#
#
# At random state 77, the training accuracy is:- 0.9807912993219895
# At randoom stae 77, the training accuracy is:- -0.39683364315173186
#
#
# At random state 78, the training accuracy is:- 0.9430858386844709
# At randoom stae 78, the training accuracy is:- 0.8557558852427897
#
#
# At random state 79, the training accuracy is:- 0.9614787554910526
# At randoom stae 79, the training accuracy is:- 0.6484178616999856
#
#
# At random state 80, the training accuracy is:- 0.9698463485850972
# At randoom stae 80, the training accuracy is:- 0.23756312200740026
#
#
# At random state 81, the training accuracy is:- 0.9591802259975185
# At randoom stae 81, the training accuracy is:- -1.8761397394828614
#
#
# At random state 82, the training accuracy is:- 0.9767609218924761
# At randoom stae 82, the training accuracy is:- 0.7712927921204074
#
#
# At random state 83, the training accuracy is:- 0.9460900719826132
# At randoom stae 83, the training accuracy is:- 0.8608012740024553
#
#
# At random state 84, the training accuracy is:- 0.9426787115547371
# At randoom stae 84, the training accuracy is:- 0.7638518588906631
#
#
# At random state 85, the training accuracy is:- 0.9482332232893187
# At randoom stae 85, the training accuracy is:- 0.8008466748994058
#
#
# At random state 86, the training accuracy is:- 0.9474506764736556
# At randoom stae 86, the training accuracy is:- 0.8192570984122346
#
#
# At random state 87, the training accuracy is:- 0.9555559968840478
# At randoom stae 87, the training accuracy is:- 0.687333169242967
#
#
# At random state 88, the training accuracy is:- 0.9743079218330823
# At randoom stae 88, the training accuracy is:- -3.17032698122501
#
#
# At random state 89, the training accuracy is:- 0.9563832738427783
# At randoom stae 89, the training accuracy is:- 0.42021353828063
#
#
# At random state 90, the training accuracy is:- 0.9498254888297879
# At randoom stae 90, the training accuracy is:- 0.8213452097467306
#
#
# At random state 91, the training accuracy is:- 0.9420987764787911
# At randoom stae 91, the training accuracy is:- 0.8406526148110753
#
#
# At random state 92, the training accuracy is:- 0.9456650088879208
# At randoom stae 92, the training accuracy is:- 0.8698064257719731
#
#
# At random state 93, the training accuracy is:- 0.9547993245796141
# At randoom stae 93, the training accuracy is:- 0.7227647790664317
#
#
# At random state 94, the training accuracy is:- 0.9688489645427705
# At randoom stae 94, the training accuracy is:- -0.15461249790622733
#
#
# At random state 95, the training accuracy is:- 0.949237244307237
# At randoom stae 95, the training accuracy is:- 0.5419216882637621
#
#
# At random state 96, the training accuracy is:- 0.9543111333701505
# At randoom stae 96, the training accuracy is:- 0.5026968779834661
#
#
# At random state 97, the training accuracy is:- 0.9410318499364788
# At randoom stae 97, the training accuracy is:- 0.8984158260690014
#
#
# At random state 98, the training accuracy is:- 0.9799213828296981
# At randoom stae 98, the training accuracy is:- 0.6318135647115536
#
#
# At random state 99, the training accuracy is:- 0.9441910648502446
# At randoom stae 99, the training accuracy is:- 0.9262280125446514

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 27)

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred_test = lr.predict(x_test)

# %%
print(r2_score(y_test, pred_test))
# Out:
# 0.9333854945491913

# %%
# here r2_score of our model is 93.33 which is good one.

# %%
# cross vvalidation of the model

Train_acc = r2_score(y_train, pred_train)
Test_acc = r2_score(y_test, pred_test)

from sklearn.model_selection import cross_val_score


for j in range(2,12):
    cv_score = cross_val_score(lr, x, y, cv = j)
    cv_mean = cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy for testing is {Test_acc}")
    print("\n")
# Out:
# At cross fold 2 the cv score is -2.503875475201532 and accuracy for testing is 0.9333854945491913
#
#
# At cross fold 3 the cv score is -0.025248255795737567 and accuracy for testing is 0.9333854945491913
#
#
# At cross fold 4 the cv score is 0.7536858409796714 and accuracy for testing is 0.9333854945491913
#
#
# At cross fold 5 the cv score is 0.03841364668952916 and accuracy for testing is 0.9333854945491913
#
#
# At cross fold 6 the cv score is 0.4714340432275865 and accuracy for testing is 0.9333854945491913
#
#
# At cross fold 7 the cv score is 0.5684171586787291 and accuracy for testing is 0.9333854945491913
#
#
# At cross fold 8 the cv score is 0.5270531381047265 and accuracy for testing is 0.9333854945491913
#
#
# At cross fold 9 the cv score is -1.5291371003043852 and accuracy for testing is 0.9333854945491913
#
#
# At cross fold 10 the cv score is -1.7203616059268902 and accuracy for testing is 0.9333854945491913
#
#
# At cross fold 11 the cv score is -1.7295503885941272 and accuracy for testing is 0.9333854945491913

# %%
# so at fold 4 the cv score is 75.36%  and accuracy score is 93.33%

# here we have handled the problem of overfitting and underfitting by checking the testing score.

# %%
# Hyper parameter Tunning::

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha': [0.0001,0.001,0.01,0.1,1,10], "random_state":list(range(0,10))}

la= Lasso()
clf = GridSearchCV(la, parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
la = Lasso(alpha=10,random_state=0)
la.fit(x_train,y_train)
la.score(x_train,y_train)
pred_la = la.predict(x_test)


laa = r2_score(y_test,pred_la)
laa
# Out:
# 0.8625471668264497

# %%
# for lasso model we getting the accuracy for upto the 86.25%

# %%
cv_score =cross_val_score(la,x,y,cv=3)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.7204159437109917

# %%
# Trying for the Enemble Technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'mae'],'max_features':["auto","sqrt","log2"]}

rf = RandomForestRegressor()

clf = GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
rf = RandomForestRegressor(criterion="mae", max_features="auto")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision = rf.predict(x_test)

rfs = r2_score(y_test,pred_decision)
print("R2 Score: ", rfs*100)

rfscore = cross_val_score(rf,x,y,cv=3)
rfc = rfscore.mean()
print("Cross Val Score:", rfc*100)
# Out:
# R2 Score:  53.34240098249925
# Cross Val Score: 41.35220979055318

# %%
# hence with Lasso model we are getting the 86.25% accuracy and cross validation score of upto 72%
# which is better than the Random Forest Regressor.

# %%
# model Saving

import pickle
filename = 'baseball.pkl'
pickle.dump(lr, open(filename, 'wb'))

# %%
# Conclusion

import numpy as np
a = np.array(y_test)
predicated = np.array(lr.predict(x_test))
df_com = pd.DataFrame({'original':a, "predicted":predicated}, index=range(len(a)))
df_com
# Out:
#    original  predicted
# 0        68  68.539663
# 1       100  99.434191
# 2        86  83.768049
# 3        81  83.000220
# 4        83  87.909864
# 5        79  80.568422
